# %% [markdown]
# import libraies

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# load the dataset

# %%
df=pd.read_csv("https://media.githubusercontent.com/media/D-Arpan/Data-Cleaning/refs/heads/main/Airbnb/Airbnb_Open_Data.csv")
df.to_csv('Airbnb Uncleaned Data')
# Out:
# C:\Users\EMMANUEL\AppData\Local\Temp\ipykernel_34160\352264258.py:1: DtypeWarning: Columns (25) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv("https://media.githubusercontent.com/media/D-Arpan/Data-Cleaning/refs/heads/main/Airbnb/Airbnb_Open_Data.csv")
